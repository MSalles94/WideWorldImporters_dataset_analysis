# %%
from python_source.modules.metadata import config_dateRange
 
 
config_dateRange()
# Out:
# ['2015-01-01', '2015-01-31', 2015, 1]

# %%
from python_source.modules.metadata import *

teste=MetadataManager()

# %%
teste.file_path
# Out:
# PosixPath('data_lake/config_extraction.JSON')
