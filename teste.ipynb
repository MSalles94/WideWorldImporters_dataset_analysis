# %%
from python_source.modules.metadata import metadata_configs

teste=metadata_configs()

# %%
teste.metadata
# Out:
# {'log_register': False,
#  'year': 2015,
#  'month': 1,
#  'first_date': {'year': 2015, 'month': 1},
#  'last_date': {'year': 2015, 'month': 6}}

# %%
teste.last_date
# Out:
# datetime.date(2015, 6, 1)

# %%
teste.first_date
# Out:
# datetime.date(2015, 1, 1)
