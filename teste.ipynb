# %%
from python_source.modules.metadata import MetadataManager
teste=MetadataManager()

# %%
teste.list_tables()
# Out:
# ['customers', 'orders']

# %%
teste.get(table='customers')
# Out:
# {'source_system': 'SQLServer',
#  'source_database': 'WideWorldImporters',
#  'source_schema': 'Sales',
#  'source_table': 'Customers',
#  'load_type': 'INCREMENTAL',
#  'watermark_column': 'LastEditedWhen',
#  'active': True}
